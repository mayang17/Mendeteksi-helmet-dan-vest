# %% [markdown]
# <a href="https://colab.research.google.com/github/mayang17/Mendeteksi-helmet-dan-vest/blob/main/UAS_VISIKOM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/entbappy/Computer-Vision-Matarials.git
# Out:
# Cloning into 'Computer-Vision-Matarials'...
# remote: Enumerating objects: 75, done.
# remote: Counting objects: 100% (75/75), done.
# remote: Compressing objects: 100% (74/74), done.
# remote: Total 75 (delta 27), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (75/75), 50.28 MiB | 14.12 MiB/s, done.
# Resolving deltas: 100% (27/27), done.

# %%
cd Computer-Vision-Matarials
# Out:
# /content/Computer-Vision-Matarials

# %%
ls
# Out:
#  Auto_Data_Annotation_for_image_segmentation.ipynb
#  Auto_Data_labeling_using_Florence_2.ipynb
#  Auto_image_Annotation_using_autodistil.ipynb
#  Custom_object_Detection_using_Detectron2.ipynb
#  data.zip
# 'Detect_Track_and_count_with_yolov8_&_Supervision.ipynb'
#  Fine-Tuning_Florence2/
#  LICENSE
#  Object_tracking.ipynb
#  README.md
#  Traffic_Safety_yolov5.ipynb
#  Train_a_YOLO_model_using_lightly_train.ipynb
#  training_huggingface_detr_on_custom_dataset.ipynb
#  training_object_detection_on_custom_data_yolov5.ipynb
#  Yolo11/

# %%
# !nvidia-smi
# Out:
# Sat Jun  7 23:10:43 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8             10W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 64.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 98.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 74.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 42.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.5/112.6 GB disk)

# %%
from ultralytics import YOLO
from IPython.display import Image

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="36mSChMDu4KmW1QNRu9c")
project = rf.workspace("mayang").project("smoke-detection-aiusa-godxk")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...

# %%
dataset.location
# Out:
# '/content/Smoke-Detection-1'

# %%
# !ls /content
# Out:
# runs  Smoke-Detection-1  yolo11n.pt

# %%
# !ls /content/Smoke-Detection-1
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model="yolo11n.pt" epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !yolo task=detect mode=train data={dataset.location}/data.yaml model="yolo11n.pt"  epochs=50 imgsz=640
# Out:
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
# !find /content/runs -name "confusion_matrix.png"
# Out:
# /content/runs/detect/train4/confusion_matrix.png
# /content/runs/detect/train5/confusion_matrix.png
# /content/runs/detect/train6/confusion_matrix.png

# %%
Image('/content/runs/detect/train4/confusion_matrix.png', width=600)
Image('/content/runs/detect/train5/confusion_matrix.png', width=600)
Image('/content/runs/detect/train6/confusion_matrix.png', width=600)

# %%
# Menampilkan semua confusion matrix sekaligus
display(Image('/content/runs/detect/train4/confusion_matrix.png', width=600))
display(Image('/content/runs/detect/train5/confusion_matrix.png', width=600))
display(Image('/content/runs/detect/train6/confusion_matrix.png', width=600))

# %%
Image('/content/runs/detect/train4/labels.jpg', width=600)

# %%
Image('/content/runs/detect/train4/results.png', width=600)

# %%
import os

folder_path = '/content/runs/detect/train4'
jpg_files = [f for f in os.listdir(folder_path) if f.endswith('.jpg')]
print("File JPG di train4:")
print(jpg_files)
# Out:
# File JPG di train4:
# ['val_batch2_pred.jpg', 'val_batch2_labels.jpg', 'val_batch0_pred.jpg', 'val_batch1_labels.jpg', 'train_batch2.jpg', 'val_batch0_labels.jpg', 'val_batch1_pred.jpg', 'train_batch762.jpg', 'train_batch761.jpg', 'train_batch760.jpg', 'labels.jpg', 'train_batch1.jpg', 'train_batch0.jpg', 'labels_correlogram.jpg']

# %%
from IPython.display import Image, display

# Tampilkan gambar hasil training
display(Image('/content/runs/detect/train4/train_batch0.jpg', width=600))

# %%
display(Image('/content/runs/detect/train4/val_batch2_pred.jpg', width=600))

# %%
# !ls /content/runs/detect
# Out:
# train  train2  train3  train4  train5  train6

# %%
# !find /content/runs/detect -name best.pt
# Out:
# /content/runs/detect/train4/weights/best.pt
# /content/runs/detect/train5/weights/best.pt
# /content/runs/detect/train6/weights/best.pt

# %%
# !yolo task=detect mode=predict model="/content/runs/detect/train4/weights/best.pt" conf=0.25 source="/content/Smoke-Detection-1/test/images" save=True
# Out:
# Ultralytics 8.3.152 🚀 Python-3.11.13 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,583,127 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/41 /content/Smoke-Detection-1/test/images/00218_jpg.rf.01bf17a4c2bdd91303a9e4f2a7c8909f.jpg: 448x640 5 0s, 2 3s, 7 4s, 45.3ms
# image 2/41 /content/Smoke-Detection-1/test/images/00267_jpg.rf.c9f1b2892da38304a2b045be88babba1.jpg: 640x640 2 4s, 9.9ms
# image 3/41 /content/Smoke-Detection-1/test/images/00269_jpg.rf.8469a54fcac8356284faab92ae595dea.jpg: 640x640 1 4, 8.2ms
# image 4/41 /content/Smoke-Detection-1/test/images/AightDuo0193_jpg.rf.1fd23bb731519d40112514377087fd08.jpg: 384x640 1 4, 49.0ms
# image 5/41 /content/Smoke-Detection-1/test/images/AightSird0542_jpg.rf.a26ebf39d9fa7e7d9181ebaf15acacb7.jpg: 384x640 2 4s, 9.1ms
# image 6/41 /content/Smoke-Detection-1/test/images/Aitin0036_jpg.rf.31c168d8f2db2e27cf55a370c0b9320e.jpg: 384x640 1 3, 2 4s, 8.4ms
# ...

# %%
import glob
import os
from IPython.display import Image as IPyImage, display

# Temukan folder predict terakhir berdasarkan waktu
latest_folder = max(glob.glob('/content/runs/detect/predict*/'), key=os.path.getmtime)

# Ambil 3 file gambar dari folder tersebut (misal mulai dari indeks ke-1 sampai ke-3)
image_paths = glob.glob(f'{latest_folder}/*.jpg')[1:4]

# Tampilkan gambarnya
for img_path in image_paths:
    display(IPyImage(filename=img_path, width=600))
    print("\n")
